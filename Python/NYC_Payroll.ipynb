# %% [markdown]
# # DTSC-580 Data Manipulation
#
# ## Assignment:  NYC Payroll Assignment

# %%
# common imports
import pandas as pd
import numpy as np

# %%
# import data - use dtype argument due to large file size
nyc_full = pd.read_csv('NYC_Payroll_Data.csv', dtype={'Fiscal Year': 'int', 'Payroll Number': 'float', 'Agency Name': 'str',
                                                            'Last Name': 'str','First Name': 'str','Mid Init': 'str',
                                                            'Agency Start Date': 'str','Work Location Borough': 'str','Title Description': 'str',
                                                            'Leave Status as of June 30': 'str','Base Salary': 'float','Pay Basis': 'str',
                                                            'Regular Hours': 'float', 'Regular Gross Paid': 'float', 'OT Hours': 'float',
                                                            'Total OT Paid': 'float', 'Total Other Pay': 'float'})

# %%
# make copy of data so you do not need to import again if you make a mistake and need to "reset"
nyc = nyc_full.copy()

# %%
# check information about DataFrame
nyc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4496767 entries, 0 to 4496766
# Data columns (total 17 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   Fiscal Year                 int32
#  1   Payroll Number              float64
#  2   Agency Name                 object
#  3   Last Name                   object
#  4   First Name                  object
#  5   Mid Init                    object
#  6   Agency Start Date           object
#  7   Work Location Borough       object
#  8   Title Description           object
#  9   Leave Status as of June 30  object
#  10  Base Salary                 float64
#  11  Pay Basis                   object
#  12  Regular Hours               float64
#  13  Regular Gross Paid          float64
#  14  OT Hours                    float64
#  15  Total OT Paid               float64
#  16  Total Other Pay             float64
# dtypes: float64(7), int32(1), object(9)
# memory usage: 566.1+ MB

# %%
# check first five rows of data
nyc.head()
# Out:
#    Fiscal Year  Payroll Number                     Agency Name  Last Name  \
# 0         2020            17.0  OFFICE OF EMERGENCY MANAGEMENT    BEREZIN
# 1         2020            17.0  OFFICE OF EMERGENCY MANAGEMENT     GEAGER
# 2         2020            17.0  OFFICE OF EMERGENCY MANAGEMENT     RAMANI
# 3         2020            17.0  OFFICE OF EMERGENCY MANAGEMENT      ROTTA
# 4         2020            17.0  OFFICE OF EMERGENCY MANAGEMENT  WILSON II
#
#   First Name Mid Init Agency Start Date Work Location Borough  \
# 0    MIKHAIL      NaN        08/10/2015              BROOKLYN
# 1   VERONICA        M        09/12/2016              BROOKLYN
# 2   SHRADDHA      NaN        02/22/2016              BROOKLYN
# 3   JONATHAN        D        09/16/2013              BROOKLYN
# 4     ROBERT        P        04/30/2018              BROOKLYN
#
#                 Title Description Leave Status as of June 30  Base Salary  \
# ...

# %% [markdown]
# If you were to research the values in the DataFrame further, you will notice that there are some values in lowercase and most are listed in all uppercase.  Because of this, run the function below that will transform all characters to uppercase to be consistent with the majority of the data.

# %%
# run this code block
def upper_case(df):
    '''
    Takes as input the `nyc` DataFrame. 
    Then capitlizes each character in columns with "object" data type.
    '''
    # iterating over each column in the DataFrame
    for col in df.columns:
        # checking datatype of each column
        if df[col].dtype == 'object':
            # applying upper function on column
            df[col] = df[col].str.upper()

upper_case(nyc)

# %% [markdown]
# **Q1:** How many rows are contained in the full dataset?

# %%
len(nyc.index)
# Out:
# 4496767

# %% [markdown]
# *Note:  Most of the following questions refer to the 2021 fiscal year data.  It might help if you create a new DataFrame for only 2021 data.*

# %%
data21=nyc.loc[(nyc['Fiscal Year'] ==2021)]
data21
# Out:
#          Fiscal Year  Payroll Number                    Agency Name  \
# 3923290         2021           996.0          NYC HOUSING AUTHORITY
# 3923291         2021           996.0          NYC HOUSING AUTHORITY
# 3923292         2021           816.0  DEPT OF HEALTH/MENTAL HYGIENE
# 3923293         2021           816.0  DEPT OF HEALTH/MENTAL HYGIENE
# 3923294         2021           816.0  DEPT OF HEALTH/MENTAL HYGIENE
# ...              ...             ...                            ...
# 4496762         2021           742.0         DEPT OF ED PEDAGOGICAL
# 4496763         2021           902.0        BRONX DISTRICT ATTORNEY
# 4496764         2021           742.0         DEPT OF ED PEDAGOGICAL
# 4496765         2021           742.0         DEPT OF ED PEDAGOGICAL
# 4496766         2021           740.0  DEPARTMENT OF EDUCATION ADMIN
#
#            Last Name First Name Mid Init Agency Start Date  \
# 3923290  MUSTACIUOLO       VITO        J        02/26/2018
# ...

# %% [markdown]
# **Q2:** How many individuals are represented using only the 2021 fiscal year data?

# %%
Q2=len(data21)
Q2
# Out:
# 573477

# %% [markdown]
# **Q3:** Who had the highest base salary in 2021?  What was his/her base salary?  What Agency did he/she work for?  What was his/her title?

# %%
Q3= data21.loc[data21['Base Salary'].idxmax()]
Q3
# Out:
# Fiscal Year                                    2021
# Payroll Number                                996.0
# Agency Name                   NYC HOUSING AUTHORITY
# Last Name                                      RUSS
# First Name                                  GREGORY
# Mid Init                                          P
# Agency Start Date                        08/12/2019
# Work Location Borough                     MANHATTAN
# Title Description                             CHAIR
# Leave Status as of June 30                   ACTIVE
# Base Salary                                414707.0
# Pay Basis                                 PER ANNUM
# Regular Hours                                1820.0
# Regular Gross Paid                        413518.05
# OT Hours                                        0.0
# Total OT Paid                                   0.0
# Total Other Pay                               500.0
# Name: 3923291, dtype: object

# %% [markdown]
# **Q4:** List the top 5 employees with the highest regular gross pay in 2021.

# %%
Q4=data21.sort_values(by=['Regular Gross Paid'],ascending=False)
Q4
# Out:
#          Fiscal Year  Payroll Number                    Agency Name  \
# 3923291         2021           996.0          NYC HOUSING AUTHORITY
# 3923299         2021            15.0      OFFICE OF THE COMPTROLLER
# 3923304         2021            67.0      ADMIN FOR CHILDREN'S SVCS
# 3923321         2021             8.0          OFFICE OF THE ACTUARY
# 3923329         2021            15.0      OFFICE OF THE COMPTROLLER
# ...              ...             ...                            ...
# 4496755         2021           742.0         DEPT OF ED PEDAGOGICAL
# 4496757         2021           742.0         DEPT OF ED PEDAGOGICAL
# 4496758         2021           745.0  DEPT OF ED HRLY SUPPORT STAFF
# 4496760         2021           745.0  DEPT OF ED HRLY SUPPORT STAFF
# 4496766         2021           740.0  DEPARTMENT OF EDUCATION ADMIN
#
#          Last Name First Name Mid Init Agency Start Date  \
# 3923291       RUSS    GREGORY        P        08/12/2019
# ...

# %% [markdown]
# **Q5:** Which employee had the highest total OT paid in 2021?

# %%
Q5= data21.loc[data21['Total OT Paid'].idxmax()]
Q5
# Out:
# Fiscal Year                                    2021
# Payroll Number                                996.0
# Agency Name                   NYC HOUSING AUTHORITY
# Last Name                                   PROCIDA
# First Name                                   ROBERT
# Mid Init                                        NaN
# Agency Start Date                        04/13/1987
# Work Location Borough                         BRONX
# Title Description                SUPERVISOR PLUMBER
# Leave Status as of June 30                   ACTIVE
# Base Salary                                  387.03
# Pay Basis                                   PER DAY
# Regular Hours                                1820.0
# Regular Gross Paid                         100627.8
# OT Hours                                     2249.5
# Total OT Paid                             248749.72
# Total Other Pay                             7215.34
# Name: 3923298, dtype: object

# %% [markdown]
# **Q6:** Which employee that was still active as of June 30th had the highest total other pay in 2021?

# %%
Q6=data21.sort_values(by=['Total Other Pay'],ascending=False).head()
Q6
# Out:
#          Fiscal Year  Payroll Number                Agency Name    Last Name  \
# 3923297         2021            56.0          POLICE DEPARTMENT          NaN
# 3923390         2021            56.0          POLICE DEPARTMENT          NaN
# 3923290         2021           996.0      NYC HOUSING AUTHORITY  MUSTACIUOLO
# 3923296         2021           462.0  GUTTMAN COMMUNITY COLLEGE     EVENBECK
# 3924320         2021            56.0          POLICE DEPARTMENT          NaN
#
#         First Name Mid Init Agency Start Date Work Location Borough  \
# 3923297        NaN      NaN        07/16/1984             MANHATTAN
# 3923390        NaN      NaN        07/03/1989             MANHATTAN
# 3923290       VITO        J        02/26/2018             MANHATTAN
# 3923296      SCOTT        E        04/17/2011             MANHATTAN
# 3924320        NaN      NaN        07/08/1985             MANHATTAN
#
#                                      Title Description  \
# ...

# %% [markdown]
# **Q7:**  According to the Data Dictionary, an employee's total gross pay is equal to the sum of their regular gross pay, total overtime pay, and total other pay.  Create a column called `Total Gross Paid` in the `nyc` DataFrame that sums those three respective pay columns for each employee.
#
# *Note: After adding this column to the `nyc` DataFrame, I would suggest that you overwrite your 2021 DataFrame again with only 2021 data to make it easier to answer the questions below.*
#
# Which 10 individuals had the highest total gross pay in 2021?

# %% [markdown]
# **Q8:** What is the average, median, and standard deviation for total gross pay for all individuals in 2021?

# %%
### ENTER CODE HERE ###

# %%
### ENTER CODE HERE ###

# %%
### ENTER CODE HERE ###

# %% [markdown]
# **Q9:** How many different agencies are represented in the 2021 data?  What are the names of the agencies?

# %%
### ENTER CODE HERE ###

# %%
### ENTER CODE HERE ###

# %% [markdown]
# **Q10:** What agencies had the highest and lowest median total gross pay in 2021?

# %%
Q13=data21.groupby('Work Location Borough').median()
Q13.sort_values(by=['Regular Gross Paid'],ascending=False).head(4)
# Out:
#                        Fiscal Year  Payroll Number  Base Salary  \
# Work Location Borough
# ALBANY                      2021.0           102.0      83430.0
# DUTCHESS                    2021.0           826.0      64397.0
# WASHINGTON DC               2021.0             2.0     148278.5
# ULSTER                      2021.0           826.0      77070.0
#
#                        Regular Hours  Regular Gross Paid  OT Hours  \
# Work Location Borough
# ALBANY                        1820.0            85689.53      0.00
# DUTCHESS                      2080.0            84016.85     33.75
# WASHINGTON DC                 1820.0            80236.23      0.00
# ULSTER                        1820.0            76853.09      0.00
#
#                        Total OT Paid  Total Other Pay
# Work Location Borough
# ALBANY                          0.00           115.92
# DUTCHESS                     1701.68           856.90
# WASHINGTON DC                   0.00           402.88
# ...

# %%
Q13=data21.groupby('Work Location Borough').max()
Q13.sort_values(by=['Base Salary'],ascending=True).head(4)

# %% [markdown]
# **Q11:** How much did Mayor Bill de Blasio make in 2021 (total gross pay)?  Who had the highest total gross pay in the Mayor's office? When was Mayor Bill de Blasio's start date in the Mayor's office?

# %%
Q11=data21.loc[(data21['Agency Name'] =='NYC HOUSING AUTHORITY')].sort_values(by=['Base Salary'],ascending=False).head(5)
Q11
# Out:
#   File "C:\Users\fiber\AppData\Local\Temp/ipykernel_22272/3320689631.py", line 2
#     Q11
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# **Q12:** What was the average base salary per work location in 2021?

# %%
#Q12=data21.groupby('Work Location Borough').mean()
#Q12

# %% [markdown]
# **Q13:** For the work location that has the highest average base salary above, which individual in that location makes the highest base salary?

# %%
Q47=data21.loc[(data21['Work Location Borough'] =='SCHOHARIE')].sort_values(by=['Base Salary'],ascending=False)
Q47
# Out:
#          Fiscal Year  Payroll Number                     Agency Name  \
# 3945224         2021           826.0  DEPT OF ENVIRONMENT PROTECTION
# 3977095         2021           826.0  DEPT OF ENVIRONMENT PROTECTION
# 4034761         2021           826.0  DEPT OF ENVIRONMENT PROTECTION
# 4082520         2021           826.0  DEPT OF ENVIRONMENT PROTECTION
# 4080622         2021           826.0  DEPT OF ENVIRONMENT PROTECTION
# 4079038         2021           826.0  DEPT OF ENVIRONMENT PROTECTION
# 4112644         2021           826.0  DEPT OF ENVIRONMENT PROTECTION
# 4087470         2021           826.0  DEPT OF ENVIRONMENT PROTECTION
# 4104000         2021           826.0  DEPT OF ENVIRONMENT PROTECTION
# 4108478         2021           826.0  DEPT OF ENVIRONMENT PROTECTION
# 4120740         2021           826.0  DEPT OF ENVIRONMENT PROTECTION
# 4118273         2021           826.0  DEPT OF ENVIRONMENT PROTECTION
# 4113363         2021           826.0  DEPT OF ENVIRONMENT PROTECTION
# ...

# %% [markdown]
# **Q14:** Group the 2021 data by work location and then agency name.  What are the five largest median base salaries from that grouped data?

# %%
### ENTER CODE HERE ###

# %% [markdown]
# **Q15:** How has the cumulative total gross pay for all individuals changed over time?  Be prepared to answer just basic questions such as has it mostly increased or decreased, what year had the highest total gross pay, etc.

# %%
### ENTER CODE HERE ###

# %% [markdown]
# **Q16:** How has the total number of employees for each fiscal year changed over time?  Again, be prepared to answer just some basic questions.

# %%
### ENTER CODE HERE ###

# %% [markdown]
# **Q17:** Who are the 2 top base salary employees per work location borough for 2021?  You may want to think about creating a custom function to make this easier to answer.

# %%
Q12=data21.groupby('Work Location Borough').mean()
Q12
# Out:
#                        Fiscal Year  Payroll Number    Base Salary  \
# Work Location Borough
# ALBANY                      2021.0      399.866667   91296.344000
# BRONX                       2021.0      371.114652   55290.460386
# BROOKLYN                    2021.0      360.372401   59288.815687
# DELAWARE                    2021.0      824.951220   65365.190366
# DUTCHESS                    2021.0      826.000000   60963.991379
# GREENE                      2021.0      826.000000   72366.213333
# MANHATTAN                   2021.0      619.013203   43044.492124
# NASSAU                      2021.0      740.000000   29930.476500
# ORANGE                      2021.0      740.000000   57403.000000
# OTHER                       2021.0      742.014099  120124.578298
# PUTNAM                      2021.0      826.000000   63959.932895
# QUEENS                      2021.0      414.427770   58846.691720
# RICHMOND                    2021.0      484.682449   58241.712893
# ...

# %%
Q188=data21.groupby('Agency').median()
Q188
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22272/4258457824.py in <module>
# ----> 1 Q188=data21.groupby('Agency').median()
#       2 Q188
#
# NameError: name 'data21' is not defined

# %% [markdown]
# **Q18:** Who are the 2 top total gross paid employees per borough for 2021?  If you made a custom function for the previous question, this will be much easier to answer.

# %%
### ENTER CODE HERE ###

# %% [markdown]
# **Q19:** For 2021, what percentage of individuals earned income per annum, per day and per hour?

# %%
### ENTER CODE HERE ###

# %% [markdown]
# **Q20:** Create a pivot table using the median of total gross pay with the index by agency name and columns broken down by pay basis category for 2021.  Include `margins=True`.  Be prepared to answer questions based on this pivot table.

# %%
hh=data21.pivot_table(index=['Pay Basis','Agency Name'],margins=True)
hh
# Out:
#                                             Base Salary  Fiscal Year  \
# Pay Basis       Agency Name
# PER ANNUM       ADMIN FOR CHILDREN'S SVCS  69381.100013         2021
#                 ADMIN TRIALS AND HEARINGS  77877.436306         2021
#                 BOARD OF CORRECTION        94507.127586         2021
#                 BOARD OF ELECTION          55658.955787         2021
#                 BOROUGH PRESIDENT-BRONX    82240.722222         2021
# ...                                                 ...          ...
# PRORATED ANNUAL QUEENS COMMUNITY BOARD #6  22008.000000         2021
#                 QUEENS COMMUNITY BOARD #7  23389.500000         2021
#                 QUEENS COMMUNITY BOARD #9  21356.000000         2021
#                 TAX COMMISSION             25677.000000         2021
# All                                        50965.870949         2021
#
#                                              OT Hours  Payroll Number  \
# Pay Basis       Agency Name
# ...

# %% [markdown]
# **Q21:** What positions (grouped by titles) pay the most based on the median total gross pay in 2021?  Show the top 10.

# %%
### ENTER CODE HERE ###

# %% [markdown]
# **Q22:** What are the top 10 agencies that have the most total number of overtime hours for 2021?

# %%
Q13=data21.groupby('Agency Name').sum()
Q13.sort_values(by=['OT Hours'],ascending=False).head(10)

# %% [markdown]
# **Q23:** Attempt to do this in one line of code by using `agg`.  For the 2021 data, groupby the agency name and get the mean for the base salary, the median for the total overtime paid, and the standard deviation for the total gross paid.  Save this as an object and be prepared to index it.

# %%
### ENTER CODE HERE ###

# %% [markdown]
# **Q24:** What is the average base salary for anyone with `DATABASE` in their title description for 2021?

# %%
### ENTER CODE HERE ###

# %% [markdown]
# **Q25:** Select only the 2021 individuals that get paid on a `per Annum` basis.  Create a Series so that for each Agency, you calculate the range of the highest base salary for that agency minus the lowest base salary for that agency.  Be prepared to index into this Series to answer questions.
#
# Hint: I created a custom function similar to what we did in the "Data Aggregation and Grouping using Flags Data" module example.

# %%
lastdf=data21.loc[(data21['Pay Basis'] =='PER ANNUM')]
lastdf2=lastdf['Regular Gross Paid'].median()
lastdf2
